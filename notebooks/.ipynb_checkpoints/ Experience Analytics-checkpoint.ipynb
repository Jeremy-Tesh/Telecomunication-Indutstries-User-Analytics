# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import sys  
sys.path.insert(0, '../scripts')
import utilities

df = pd.read_csv('../clean_csv_data/clean_df.csv')

# %%
df.head()
# Out:
#                       Unnamed: 0     Bearer Id                Start  Start ms  \
# 0  1970-01-01 00:00:00.000000000  1.311448e+19  2019-04-04 12:01:18     770.0
# 1  1970-01-01 00:00:00.000000001  1.311448e+19  2019-04-09 13:04:04     235.0
# 2  1970-01-01 00:00:00.000000002  1.311448e+19  2019-04-09 17:42:11       1.0
# 3  1970-01-01 00:00:00.000000003  1.311448e+19  2019-04-10 00:31:25     486.0
# 4  1970-01-01 00:00:00.000000004  1.311448e+19  2019-04-12 20:10:23     565.0
#
#                    End  End ms  Dur. (ms)          IMSI  MSISDN/Number  \
# 0  2019-04-25 14:35:31   662.0    86399.0  2.082014e+14   3.366496e+10
# 1  2019-04-25 08:15:48   606.0    86399.0  2.082019e+14   3.368185e+10
# 2  2019-04-25 11:58:13   652.0    86399.0  2.082003e+14   3.376063e+10
# 3  2019-04-25 07:36:35   171.0    86399.0  2.082014e+14   3.375034e+10
# 4  2019-04-25 10:40:32   954.0    86399.0  2.082014e+14   3.369980e+10
#
# ...

# %%
# aggregate of Average throughput UL for each user
utilities.find_agg(df, "MSISDN/Number","Avg Bearer TP UL (kbps)" ,"sum", "Avg throughput UL per user", 10, order=False )
# Out:
#            MSISDN/Number  Avg throughput UL per user
# 29539  33,658,124,130.00                  167,024.00
# 29313  33,658,075,438.00                  163,585.00
# 100319 33,763,744,937.00                  161,563.00
# 69910  33,668,708,263.00                  159,430.00
# 25134  33,650,520,779.00                  145,320.00
# 99990  33,763,586,476.00                  138,359.00
# 39898  33,660,394,384.00                  137,330.00
# 36257  33,659,546,392.00                  127,412.00
# 66417  33,667,600,457.00                  127,200.00
# 59015  33,665,182,467.00                  124,387.00

# %%
# aggregate of Average throughput UL for each user
utilities.find_agg(df, "MSISDN/Number","Avg Bearer TP UL (kbps)" ,"sum", "Avg throughput UL per user", 10, order=False )
# Out:
#            MSISDN/Number  Avg throughput UL per user
# 29539  33,658,124,130.00                  167,024.00
# 29313  33,658,075,438.00                  163,585.00
# 100319 33,763,744,937.00                  161,563.00
# 69910  33,668,708,263.00                  159,430.00
# 25134  33,650,520,779.00                  145,320.00
# 99990  33,763,586,476.00                  138,359.00
# 39898  33,660,394,384.00                  137,330.00
# 36257  33,659,546,392.00                  127,412.00
# 66417  33,667,600,457.00                  127,200.00
# 59015  33,665,182,467.00                  124,387.00

# %%
utilities.find_agg(df, "MSISDN/Number","Avg Bearer TP DL (kbps)" ,"sum", "Avg throughput DL per user", 10, order=False )
# Out:
#           MSISDN/Number  Avg throughput DL per user
# 97584 33,762,333,464.00                  846,163.00
# 69910 33,668,708,263.00                  680,994.00
# 36257 33,659,546,392.00                  670,930.00
# 69020 33,668,425,947.00                  658,687.00
# 84486 33,698,174,760.00                  606,931.00
# 73146 33,669,946,573.00                  581,209.00
# 13141 33,625,700,673.00                  556,109.00
# 31726 33,658,581,169.00                  510,852.00
# 74585 33,672,505,906.00                  480,466.00
# 26187 33,650,760,733.00                  475,751.00

# %%
# aggregate of Average RTT UL for each user
utilities.find_agg(df, "MSISDN/Number","Avg RTT UL (ms)" ,"sum", "Avg RTT UL per user", 10, order=False )
# Out:
#            MSISDN/Number  Avg RTT UL per user
# 37287  33,659,778,586.00             7,120.00
# 17134  33,633,298,261.00             5,607.00
# 94139  33,761,092,970.00             5,422.00
# 65118  33,667,163,239.00             5,414.00
# 14494  33,627,850,141.00             5,295.00
# 96962  33,762,057,942.00             5,248.00
# 69218  33,668,497,162.00             4,682.00
# 18351  33,636,368,478.00             4,026.00
# 103348 33,778,078,390.00             3,923.00
# 60161  33,665,482,928.00             3,851.00

# %%
utilities.find_agg(df, "MSISDN/Number","Avg RTT DL (ms)" ,"sum", "Avg RTT DL per user", 10, order=False )
# Out:
#            MSISDN/Number  Avg RTT DL per user
# 47983  33,662,317,023.00            96,923.00
# 41944  33,660,874,265.00            64,666.00
# 80249  33,683,692,867.00            54,847.00
# 85683  33,698,551,167.00            45,923.00
# 96414  33,761,813,523.00            36,977.00
# 70142  33,668,791,629.00            36,125.00
# 93844  33,760,941,100.00            26,971.00
# 1713   33,606,788,933.00            26,250.00
# 74240  33,671,816,754.00            25,602.00
# 104325 33,781,865,588.00            25,374.00

# %%
# aggregate of Handset types of each user
utilities.find_agg(df, "MSISDN/Number","Handset Type" ,"count", "Handset type per user", 10, order=False )
# Out:
#           MSISDN/Number  Handset type per user
# 13526 33,626,320,676.00                     18
# 13180 33,625,779,332.00                     17
# 6437  33,614,892,860.00                     17
# 37052 33,659,725,664.00                     16
# 92923 33,760,536,639.00                     15
# 76363 33,675,877,202.00                     15
# 65118 33,667,163,239.00                     13
# 13994 33,627,080,969.00                     12
# 1279  33,604,515,716.00                     12
# 92577 33,760,413,819.00                     12

# %%
# aggregate of TCP retransmission DL of each user
utilities.find_agg(df, "MSISDN/Number","TCP DL Retrans. Vol (Bytes)" ,"sum", "Avg TCP retransmission per user", 10, order=False )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_32097/862183393.py in <module>
#       1 # aggregate of TCP retransmission DL of each user
# ----> 2 utilities.find_agg(df, "MSISDN/Number","TCP DL Retrans. Vol (Bytes)" ,"sum", "Avg TCP retransmission per user", 10, order=False )
#
# ~/Desktop/10Academy/week1/notebooks/../scripts/utilities.py in find_agg(df, agg_column, wanted_col, agg_metric, col_name, top, order)
#      15 def find_agg(df:pd.DataFrame, agg_column:str, wanted_col:str,agg_metric:str, col_name:str, top:int, order=False )->pd.DataFrame:
#      16     """ This function calculates aggregate of column """
# ---> 17     new_df = df.groupby(agg_column)[wanted_col].agg(agg_metric).reset_index(name=col_name).\
#      18     sort_values(by=col_name, ascending=order)[:top]
#      19
#
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                        0
# Bearer Id                         0
# Start                             0
# Start ms                          0
# End                               0
# End ms                            0
# Dur. (ms)                         0
# IMSI                              0
# MSISDN/Number                     0
# IMEI                              0
# Last Location Name                0
# Avg RTT DL (ms)                   0
# Avg RTT UL (ms)                   0
# Avg Bearer TP DL (kbps)           0
# Avg Bearer TP UL (kbps)           0
# DL TP < 50 Kbps (%)               0
# 50 Kbps < DL TP < 250 Kbps (%)    0
# 250 Kbps < DL TP < 1 Mbps (%)     0
# DL TP > 1 Mbps (%)                0
# UL TP < 10 Kbps (%)               0
# 10 Kbps < UL TP < 50 Kbps (%)     0
# 50 Kbps < UL TP < 300 Kbps (%)    0
# UL TP > 300 Kbps (%)              0
# Activity Duration DL (ms)         0
# Activity Duration UL (ms)         0
# Dur. (ms).1                       0
# ...
