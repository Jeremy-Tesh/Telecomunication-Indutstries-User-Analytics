# %%
import pandas as pd
import numpy as np

# %%
#import clean data
df_clean = pd.read_csv('../clean_csv_data/clean_df.csv')
sessions_df = pd.read_csv('../clean_csv_data/sessions_df.csv')
scaled_sessions_df =pd.read_csv('../clean_csv_data/scaled_sessions_df.csv')

# %%
# The top 10 handsets used by the customers
top10_handsets_customers = df_clean[['Handset Type','IMSI']].groupby(['Handset Type'])
#top10 = data.sort_values(['Handset Type','IMSI'], ascending=False).groupby('Handset Type')
top10_handsets_customers = top10_handsets_customers['IMSI'].nunique()
top10_handsets_customers = top10_handsets_customers.reset_index(name='Total')
top10_handsets_customers = top10_handsets_customers.sort_values(['Total'], ascending=False)
top10_handsets_customers.head(10)
# Out:
#                       Handset Type  Total
# 316               Huawei B528S-23A  10130
# 53         Apple iPhone 6S (A1688)   6120
# 49          Apple iPhone 6 (A1586)   5765
# 1393                     undefined   5684
# 59          Apple iPhone 7 (A1778)   4268
# 73         Apple iPhone Se (A1723)   3424
# 66          Apple iPhone 8 (A1905)   3230
# 953   Samsung Galaxy S8 (Sm-G950F)   2880
# 78         Apple iPhone Xr (A2105)   2672
# 836     Samsung Galaxy A5 Sm-A520F   2487

# %%
# top 3 handset manufacturers

top3_handset_manufacturers = df_clean['Handset Manufacturer'].value_counts().head(3)
top3_handset_manufacturers
# Out:
# Apple      59464
# Samsung    40579
# Huawei     34366
# Name: Handset Manufacturer, dtype: int64

# %%
# top 5 handsets per top 3

top5_handset_per_top3 = df_clean[df_clean["Handset Manufacturer"].isin(top3_handset_manufacturers.keys())]
top5_handset_per_top3['Handset Type'].groupby(df_clean['Handset Manufacturer']).apply(lambda x: x.value_counts().head(5))
# Out:
# Handset Manufacturer
# Apple                 Apple iPhone 6S (A1688)            9413
#                       Apple iPhone 6 (A1586)             9012
#                       Apple iPhone 7 (A1778)             6304
#                       Apple iPhone Se (A1723)            5176
#                       Apple iPhone 8 (A1905)             4985
# Huawei                Huawei B528S-23A                  19727
#                       Huawei E5180                       2074
#                       Huawei P20 Lite Huawei Nova 3E     2018
#                       Huawei P20                         1479
#                       Huawei Y6 2018                      997
# Samsung               Samsung Galaxy S8 (Sm-G950F)       4480
#                       Samsung Galaxy A5 Sm-A520F         3708
#                       Samsung Galaxy J5 (Sm-J530)        3682
#                       Samsung Galaxy J3 (Sm-J330)        3464
#                       Samsung Galaxy S7 (Sm-G930X)       3176
# Name: Handset Type, dtype: int64

# %% [markdown]
# #  overview of the users’ behavior

# %%
# Number of xDR sessions
number_of_xDR_sessions = df_clean.groupby(['IMSI'])['Bearer Id'].count()
number_of_xDR_sessions.head(5)
# Out:
# IMSI
# 2.040471e+14    1
# 2.040808e+14    1
# 2.082001e+14    1
# 2.082001e+14    1
# 2.082001e+14    2
# Name: Bearer Id, dtype: int64

# %%
number_of_xDR_sessions.describe()
# Out:
# count    95818.000000
# mean         1.554353
# std         48.124629
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max      14896.000000
# Name: Bearer Id, dtype: float64

# %%
#Session duration
session_duration = df_clean.groupby(['IMSI'])['Dur. (ms)'].sum()
session_duration.head(5)
# Out:
# IMSI
# 2.040471e+14     86399.0
# 2.040808e+14     86399.0
# 2.082001e+14     86019.0
# 2.082001e+14     86254.0
# 2.082001e+14    172798.0
# Name: Dur. (ms), dtype: float64

# %%
session_duration.describe()
# Out:
# count    9.581800e+04
# mean     1.334307e+05
# std      4.211363e+06
# min      7.142000e+03
# 25%      7.101400e+04
# 50%      8.927600e+04
# 75%      1.575428e+05
# max      1.303428e+09
# Name: Dur. (ms), dtype: float64

# %%
# the total download (DL) and upload (UL) data

dl=df_clean['Total DL'].sum()
ul=df_clean['Total UL'].sum()

print(f'Total download is {dl} and Total upload {ul} ')
# Out:
# Total download is 62064641184268.0 and Total upload 5832690905350.0

# %%
df_clean.head()
# Out:
#                       Unnamed: 0     Bearer Id                Start  Start ms  \
# 0  1970-01-01 00:00:00.000000000  1.311448e+19  2019-04-04 12:01:18     770.0
# 1  1970-01-01 00:00:00.000000001  1.311448e+19  2019-04-09 13:04:04     235.0
# 2  1970-01-01 00:00:00.000000002  1.311448e+19  2019-04-09 17:42:11       1.0
# 3  1970-01-01 00:00:00.000000003  1.311448e+19  2019-04-10 00:31:25     486.0
# 4  1970-01-01 00:00:00.000000004  1.311448e+19  2019-04-12 20:10:23     565.0
#
#                    End  End ms  Dur. (ms)          IMSI  MSISDN/Number  \
# 0  2019-04-25 14:35:31   662.0    86399.0  2.082014e+14   3.366496e+10
# 1  2019-04-25 08:15:48   606.0    86399.0  2.082019e+14   3.368185e+10
# 2  2019-04-25 11:58:13   652.0    86399.0  2.082003e+14   3.376063e+10
# 3  2019-04-25 07:36:35   171.0    86399.0  2.082014e+14   3.375034e+10
# 4  2019-04-25 10:40:32   954.0    86399.0  2.082014e+14   3.369980e+10
#
#            IMEI  ...  Netflix DL  Netflix UL    Gaming DL   Gaming UL  \
# 0  3.552121e+13  ...   8198936.0   9656251.0  278082303.0  14344150.0
# 1  3.579401e+13  ...  18338413.0  17227132.0  608750074.0   1170709.0
# 2  3.528151e+13  ...  17587794.0   6163408.0  229584621.0    395630.0
# 3  3.535661e+13  ...  13994646.0   1097942.0  799538153.0  10849722.0
# 4  3.540701e+13  ...  17124581.0    415218.0  527707248.0   3529801.0
#
#       Other DL    Other UL    Total UL     Total DL        difference  \
# 0  171744450.0   8814393.0  36749741.0  308879636.0  21 days 02:34:13
# 1  526904238.0  15055145.0  53800391.0  653384965.0  15 days 19:11:44
# 2  410692588.0   4215763.0  27883638.0  279807335.0  15 days 18:16:02
# 3  749039933.0  12797283.0  43324218.0  455870838.0  15 days 07:05:10
# 4  550709500.0  13910322.0  38542814.0  569138589.0  12 days 14:30:09
#
#     duration
# 0  1823653.0
# 1  1365104.0
# 2  1361762.0
# 3  1321510.0
# 4  1089009.0
#
# [5 rows x 48 columns]

# %%
# the total download (DL) and upload (UL) data
total_DL_UL = df_clean.groupby(['IMEI'])[['Total UL', 'Total DL']].sum()
total_DL_UL.head(5)
# Out:
#                 Total UL     Total DL
# IMEI
# 4.400152e+11  39425114.0  196385061.0
# 4.402138e+11  24856321.0  133661264.0
# 1.194901e+12  44409558.0  455870838.0
# 1.198201e+12  54841047.0  791029122.0
# 1.202601e+12  38070613.0  455870838.0

# %%
total_DL_UL.describe()
# Out:
#            Total UL      Total DL
# count  1.068620e+05  1.068620e+05
# mean   5.458152e+07  5.807924e+08
# std    3.329054e+07  4.153603e+08
# min    2.866892e+06  8.827082e+06
# 25%    3.639365e+07  3.148135e+08
# 50%    4.367728e+07  4.980012e+08
# 75%    6.208007e+07  7.281781e+08
# max    7.046113e+08  7.445570e+09

# %%
# the total data volume (in Bytes) during this session for each application
total_data_volume = df_clean[['IMSI', 'Dur. (ms)' ,'Total UL', 'Total DL', 'Social Media DL',
                        'Social Media UL', 'Google DL', 'Google UL', 
                        'Email DL', 'Email UL', 'Youtube DL', 'Youtube UL', 
                        'Netflix DL', 'Netflix UL', 'Gaming DL', 'Gaming UL', 
                        'Other DL', 'Other UL']].groupby(['IMSI']).sum()
total_data_volume.head()
# Out:
#               Dur. (ms)    Total UL     Total DL  Social Media DL  \
# IMSI
# 2.040471e+14    86399.0  41141014.0   78697597.0        1500145.0
# 2.040808e+14    86399.0  37295915.0  194828056.0         668596.0
# 2.082001e+14    86019.0  53794658.0   31376981.0        3073697.0
# 2.082001e+14    86254.0  33583272.0  392918313.0        2542767.0
# 2.082001e+14   172798.0  71325004.0  961767023.0        3326811.0
#
#               Social Media UL   Google DL  Google UL   Email DL   Email UL  \
# IMSI
# 2.040471e+14          45943.0   5985089.0  3233558.0  2518425.0   812549.0
# 2.040808e+14          46628.0   8572779.0  1865881.0   842279.0   678492.0
# 2.082001e+14          49084.0    603691.0  1020971.0  3076735.0   580766.0
# 2.082001e+14          34337.0  10699827.0  3111651.0  3248863.0   606871.0
# 2.082001e+14          99905.0   9118088.0  2547799.0  4225757.0  1338705.0
#
#               Youtube DL  Youtube UL  Netflix DL  Netflix UL    Gaming DL  \
# IMSI
# 2.040471e+14  18980320.0  21960390.0  21621336.0   7224894.0   28092282.0
# 2.040808e+14   9839889.0   2120016.0  10340908.0  16251392.0  164563605.0
# 2.082001e+14   5556563.0  14325876.0  15305361.0  16525201.0    3760934.0
# 2.082001e+14  22414714.0   3242918.0  10065639.0  17720213.0  343946503.0
# 2.082001e+14   4046597.0   9793604.0  30748449.0  26594966.0  910301321.0
#
#                Gaming UL      Other DL    Other UL
# IMSI
# 2.040471e+14  14977978.0  3.891597e+08  12200737.0
# 2.040808e+14  13485133.0  4.676781e+08   2848373.0
# 2.082001e+14   5363582.0  5.000445e+08  15929178.0
# 2.082001e+14    159394.0  3.009029e+08   8707888.0
# 2.082001e+14   7383445.0  1.055869e+09  23566580.0

# %% [markdown]
# #  Task 1.2 - Exploratory data analysis

# %%
data = total_data_volume

data.isna().sum()
# Out:
# Dur. (ms)          0
# Total UL           0
# Total DL           0
# Social Media DL    0
# Social Media UL    0
# Google DL          0
# Google UL          0
# Email DL           0
# Email UL           0
# Youtube DL         0
# Youtube UL         0
# Netflix DL         0
# Netflix UL         0
# Gaming DL          0
# Gaming UL          0
# Other DL           0
# Other UL           0
# dtype: int64

# %% [markdown]
# # Non graphical univariate analysis

# %%
def format_float(value):
    return f'{value:,.2f}'

def convert_bytes_to_megabytes(df, bytes_data):
    megabyte = 1*10e+5
    df[bytes_data] = df[bytes_data] / megabyte
    return df[bytes_data]

def fix_outlier(df, column_list):
    for column in column_list:
        df[column] = np.where(df[column] > df[column].quantile(0.95), df[column].mean(),df[column])
    
    return df

pd.options.display.float_format = format_float

# %%
data = fix_outlier(data, list(data.columns))

# %%
data.describe().transpose()
# Out:
#                     count           mean            std          min  \
# Dur. (ms)       95,818.00     106,785.74      59,643.81     7,142.00
# Total UL        95,818.00  49,709,359.47  20,548,645.41 2,866,892.00
# Total DL        95,818.00 523,958,436.07 284,073,934.27 9,046,209.00
# Social Media DL 95,818.00   2,248,898.18   1,327,961.85        12.00
# Social Media UL 95,818.00      41,226.38      24,391.20         0.00
# Google DL       95,818.00   7,201,887.65   4,236,345.76       207.00
# Google UL       95,818.00   2,574,449.16   1,521,280.06         3.00
# Email DL        95,818.00   2,241,363.31   1,319,216.38        97.00
# Email UL        95,818.00     584,975.65     346,066.40        14.00
# Youtube DL      95,818.00  14,553,467.76   8,598,795.66        53.00
# Youtube UL      95,818.00  13,779,694.53   8,120,303.93       750.00
# Netflix DL      95,818.00  14,527,773.75   8,612,622.32        42.00
# Netflix UL      95,818.00  13,779,064.86   8,157,105.80        35.00
# Gaming DL       95,818.00 528,657,930.93 311,233,538.64     2,516.00
# Gaming UL       95,818.00  10,391,231.92   6,138,299.82        59.00
# Other DL        95,818.00 527,153,493.99 312,122,462.89    30,180.00
# Other UL        95,818.00  10,335,876.65   6,096,531.38       156.00
#
#                            25%            50%            75%              max
# Dur. (ms)            71,014.00      89,276.00     141,348.50       292,538.00
# Total UL         36,436,383.50  43,742,620.50  60,872,601.24   119,764,055.00
# Total DL        316,070,961.25 498,992,862.00 684,526,054.75 1,358,707,299.00
# Social Media DL   1,178,873.50   2,268,797.00   3,080,668.25     6,030,541.00
# Social Media UL      21,620.25      41,719.50      56,480.00       111,085.00
# Google DL         3,814,585.75   7,282,193.00   9,840,363.25    19,359,968.00
# Google UL         1,345,868.50   2,602,905.00   3,528,159.00     6,923,358.00
# Email DL          1,190,796.75   2,272,349.00   3,060,119.00     6,043,300.00
# Email UL            307,185.75     588,930.00     802,501.00     1,576,437.00
# Youtube DL        7,674,063.00  14,641,746.50  19,922,622.50    39,207,077.00
# Youtube UL        7,253,770.00  13,902,834.00  18,847,792.50    36,978,966.00
# Netflix DL        7,582,334.75  14,650,776.50  19,908,313.50    39,119,904.00
# Netflix UL        7,222,368.75  13,926,074.00  18,837,301.00    37,027,987.00
# Gaming DL       280,471,664.75 534,093,185.00 722,358,403.50 1,416,947,250.00
# Gaming UL         5,472,534.00  10,486,202.50  14,230,794.75    27,898,518.00
# Other DL        276,715,593.00 531,249,259.50 720,234,999.50 1,424,211,538.00
# Other UL          5,461,661.50  10,399,058.50  14,148,183.75    27,818,841.00

# %%
def univariate_nongraphical(df):
    return df.describe()

# %%
# univariate non graphical analysis of session duration 
univariate_dur = univariate_nongraphical(data["Dur. (ms)"])
univariate_dur
# Out:
# count    95,818.00
# mean    106,785.74
# std      59,643.81
# min       7,142.00
# 25%      71,014.00
# 50%      89,276.00
# 75%     141,348.50
# max     292,538.00
# Name: Dur. (ms), dtype: float64

# %%
# univariate non graphical analysis of total UL data 
univariate_totUL = univariate_nongraphical(data["Total UL"])
univariate_totDL = univariate_nongraphical(data["Total DL"])
print(univariate_totUL,"\n")
print(univariate_totUL)
# Out:
# count        95,818.00
# mean     49,709,359.47
# std      20,548,645.41
# min       2,866,892.00
# 25%      36,436,383.50
# 50%      43,742,620.50
# 75%      60,872,601.24
# max     119,764,055.00
# Name: Total UL, dtype: float64
#
# count        95,818.00
# mean     49,709,359.47
# std      20,548,645.41
# min       2,866,892.00
# 25%      36,436,383.50
# 50%      43,742,620.50
# 75%      60,872,601.24
# max     119,764,055.00
# Name: Total UL, dtype: float64

# %%
# univariate non-graphical analysis of total volume of data in megabytes for each application
# store total dl/ul data volume for each application in a dictionary
app_names = ['Social Media', 'Google', 'Email', 'Youtube', 'Netflix', 'Gaming', 'Other']
app_ul =pd.DataFrame({app_name + ' UL' : data[app_name+' UL'] for app_name in app_names})
app_dl =pd.DataFrame({app_name+' DL' : data[app_name+' DL'] for app_name in app_names})
univariate_app_ul= univariate_nongraphical(app_ul)
univariate_app_dl =univariate_nongraphical(app_dl)
print("univariate analysis for application ul data \n\n")
print(univariate_app_ul,"\n")
print("univariate analysis for application dl data \n\n")
print(univariate_app_dl)
# Out:
# univariate analysis for application ul data
#
#
#        Social Media UL    Google UL     Email UL    Youtube UL    Netflix UL  \
# count        95,818.00    95,818.00    95,818.00     95,818.00     95,818.00
# mean         41,226.38 2,574,449.16   584,975.65 13,779,694.53 13,779,064.86
# std          24,391.20 1,521,280.06   346,066.40  8,120,303.93  8,157,105.80
# min               0.00         3.00        14.00        750.00         35.00
# 25%          21,620.25 1,345,868.50   307,185.75  7,253,770.00  7,222,368.75
# 50%          41,719.50 2,602,905.00   588,930.00 13,902,834.00 13,926,074.00
# 75%          56,480.00 3,528,159.00   802,501.00 18,847,792.50 18,837,301.00
# max         111,085.00 6,923,358.00 1,576,437.00 36,978,966.00 37,027,987.00
#
#           Gaming UL      Other UL
# count     95,818.00     95,818.00
# mean  10,391,231.92 10,335,876.65
# std    6,138,299.82  6,096,531.38
# min           59.00        156.00
# 25%    5,472,534.00  5,461,661.50
# 50%   10,486,202.50 10,399,058.50
# 75%   14,230,794.75 14,148,183.75
# max   27,898,518.00 27,818,841.00
#
# univariate analysis for application dl data
#
#
#        Social Media DL     Google DL     Email DL    Youtube DL    Netflix DL  \
# count        95,818.00     95,818.00    95,818.00     95,818.00     95,818.00
# mean      2,248,898.18  7,201,887.65 2,241,363.31 14,553,467.76 14,527,773.75
# std       1,327,961.85  4,236,345.76 1,319,216.38  8,598,795.66  8,612,622.32
# min              12.00        207.00        97.00         53.00         42.00
# 25%       1,178,873.50  3,814,585.75 1,190,796.75  7,674,063.00  7,582,334.75
# 50%       2,268,797.00  7,282,193.00 2,272,349.00 14,641,746.50 14,650,776.50
# 75%       3,080,668.25  9,840,363.25 3,060,119.00 19,922,622.50 19,908,313.50
# max       6,030,541.00 19,359,968.00 6,043,300.00 39,207,077.00 39,119,904.00
#
#              Gaming DL         Other DL
# count        95,818.00        95,818.00
# mean    528,657,930.93   527,153,493.99
# std     311,233,538.64   312,122,462.89
# min           2,516.00        30,180.00
# 25%     280,471,664.75   276,715,593.00
# 50%     534,093,185.00   531,249,259.50
# 75%     722,358,403.50   720,234,999.50
# max   1,416,947,250.00 1,424,211,538.00

# %% [markdown]
# #  Graphical Univariate Analysis

# %%
# Different function to visualize
import matplotlib.pyplot as plt
import seaborn as sns


def plot_hist(df:pd.DataFrame, column:str, color:str)->None:
   
    sns.displot(data=df, x=column, color=color, kde=True, height=7, aspect=2)
    plt.title(f'Distribution of {column}', size=20, fontweight='bold')
    plt.show()

def plot_count(df:pd.DataFrame, column:str) -> None:
    plt.figure(figsize=(12, 7))
    sns.countplot(data=df, x=column)
    plt.title(f'Distribution of {column}', size=20, fontweight='bold')
    plt.show()
    
def plot_bar(df:pd.DataFrame, x_col:str, y_col:str, title:str, xlabel:str, ylabel:str)->None:
    plt.figure(figsize=(12, 7))
    sns.barplot(data = df, x=x_col, y=y_col)
    plt.title(title, size=20)
    plt.xticks(rotation=75, fontsize=14)
    plt.yticks( fontsize=14)
    plt.xlabel(xlabel, fontsize=16)
    plt.ylabel(ylabel, fontsize=16)
    plt.show()

def plot_box(df:pd.DataFrame, x_col:str, title:str) -> None:
    plt.figure(figsize=(12, 7))
    sns.boxplot(data = df, x=x_col)
    plt.title(title, size=20)
    plt.xticks(rotation=75, fontsize=14)
    plt.show()

# %%
plot_box(data, "Dur. (ms)", "Total user session duration outliers")

# %%
plot_hist(data, "Total UL", "red")

# %%
plot_hist(data, "Total DL", "green")

# %%
#correlation matrix
cols = ['Social Media DL', 'Social Media UL', 'Google DL', 'Google UL',
            'Email DL', 'Email UL', 'Youtube DL', 'Youtube UL', 
            'Netflix DL', 'Netflix UL', 'Gaming DL', 'Gaming UL',
            'Other DL', 'Other UL']
data_corr = data[cols]
sns.heatmap(data_corr.corr(), annot = True, square=False)
# Out:
# <AxesSubplot:>
